# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain.chat_models import init_chat_model

llm = init_chat_model(
    model="gemini-3.5-flash-lite",
    model_provider="google_genai",
)

response = ""

for chunk in llm.stream("Can you explain how AI works in detail?"):
    response += chunk.text
    print(chunk.text, end="", flush=True)

# print("\n\nFull response:", response)
# Out:
# Artificial Intelligence (AI) is a broad field of computer science focused on creating systems capable of performing tasks that typically require human intelligence. These tasks include learning, reasoning, problem-solving, perception, and language understanding.
#
# To understand how AI works in detail, we need to break it down into its core components: **Data, Algorithms, Training, Hardware, and Deployment.**
#
# ---
#
# ### 1. The Fuel: Data
# AI doesn't "think" like a human; it processes data. To learn, an AI system needs massive amounts of information.
# * **Structured Data:** Spreadsheets, databases (rows and columns).
# * **Unstructured Data:** Images, text, audio, video, and code.
#
# Depending on the type of AI, data is fed into the system either labeled (e.g., "this is a picture of a cat") or unlabeled (e.g., "find patterns in these 1 million cat and dog pictures").
#
# ### 2. The Engine: Algorithms and Models
# An algorithm is a set of rules or instructions a computer follows. In AI, these algorithms form a **model**. The model is the mathematical representation of what the AI has learned.
#
# While AI encompasses many approaches (like logic-based rule systems used in the 1980s), modern AI is almost entirely driven by **Machine Learning (ML)** and its subfield, **Deep Learning (DL)**.
#
# * **Machine Learning (ML):** Instead of manually programming rules (e.g., "if an object has whiskers and purrs, it’s a cat"), programmers give the computer an algorithm and data, and let the computer figure out the rules itself.
# * **Deep Learning (DL):** A subset of ML inspired by the human brain. It uses **Artificial Neural Networks (ANNs)** with many layers (hence "deep") to process complex data like speech and images.
#
# ---
#
# ### 3. The Process: How Training Works
# Training is the process by which an AI model learns from data. This usually happens in three main ways:
#
# #### A. Supervised Learning
# * **How it works:** The AI is given input data paired with correct answers (labels).
# * **Example:** Showing an AI thousands of photos labeled "spam" or "not spam."
# * **Goal:** The AI compares its own prediction to the correct label, calculates its error (using a "loss function"), and adjusts its internal math (parameters/weights) to get closer to the right answer next time. This is done through **gradient descent** (mathematically sliding down toward the lowest possible error).
#
# #### B. Unsupervised Learning
# * **How it works:** The AI is given unlabeled data and tasked with finding hidden patterns or structures on its own.
# * **Example:** Feeding an AI customer purchase history without telling it anything. The AI might independently discover groups of customers who buy similar products (clustering).
#
# #### C. Reinforcement Learning
# * **How it works:** The AI learns by trial and error in an environment (often a simulation or game) to achieve a goal. It receives "rewards" for good actions and "penalties" for bad ones.
# * **Example:** Teaching an AI to play chess or drive a self-driving car. It tries millions of moves, remembering which ones led to winning the game.
#
# ---
#
# ### 4. The Anatomy of Modern AI: Neural Networks
# Because Deep Learning powers modern breakthroughs (like ChatGPT, Midjourney, and self-driving cars), it’s worth looking inside a neural network:
#
# 1. **Input Layer:** Receives the raw data (e.g., the pixels of an image).
# 2. **Hidden Layers:** Layers of artificial "neurons" that process the data.
#    * *Early layers* might detect simple things like edges and lines in an image.
#    * *Middle layers* combine edges to detect shapes (e.g., a circle or triangle).
#    * *Later layers* combine shapes to recognize complex features (e.g., an eye, a nose, or a full face).
# 3. **Output Layer:** Produces the final result (e.g., "This is a 95% probability of being a human face").
#
# Each connection between neurons has a **weight** (importance) and a **bias** (threshold). Learning is simply the process of tweaking these billions of weights and biases until the outputs are accurate.
#
# ---
#
# ### 5. Specialized AI Architectures
# Different tasks require different types of AI brains:
# * **Convolutional Neural Networks (CNNs):** Specialized in processing grid-like data, primarily used in computer vision (image and video recognition).
# * **Recurrent Neural Networks (RNNs) & Transformers:** Specialized in sequential data like text and speech. **Transformers** (the 'T' in GPT) revolutionized AI by using "attention mechanisms" to understand the context of words in a sentence, no matter how far apart they are.
# * **Diffusion Models:** Used in generative AI for images (like DALL-E). They start with random static (noise) and gradually shape it into a clear image based on a text prompt.
#
# ---
#
# ### 6. Hardware: The Muscle
# Training modern AI requires immense computational power.
# * **GPUs (Graphics Processing Units):** Originally built for rendering video game graphics, GPUs are exceptional at performing thousands of mathematical calculations simultaneously, making them the backbone of AI training.
# * **TPUs (Tensor Processing Units) and specialized AI chips:** Custom hardware designed specifically to accelerate machine learning workloads.
#
# ---
#
# ### Summary: From Input to Output
# When you use an AI tool today, here is what happens in milliseconds:
# 1. **Inference:** The trained model is loaded onto a server.
# 2. **You provide an input:** (e.g., "Write a poem about a robot").
# 3. **Tokenization:** The text is broken down into numbers (tokens) that the computer understands.
# 4. **Processing:** The numbers pass through billions of neural network parameters, calculating probabilities for the next best word based on everything it read during training.
# 5. **Decoding:** The output numbers are translated back into human language and displayed on your screen.
#
# Full response: Artificial Intelligence (AI) is a broad field of computer science focused on creating systems capable of performing tasks that typically require human intelligence. These tasks include learning, reasoning, problem-solving, perception, and language understanding.
#
# To understand how AI works in detail, we need to break it down into its core components: **Data, Algorithms, Training, Hardware, and Deployment.**
#
# ---
#
# ### 1. The Fuel: Data
# AI doesn't "think" like a human; it processes data. To learn, an AI system needs massive amounts of information.
# * **Structured Data:** Spreadsheets, databases (rows and columns).
# * **Unstructured Data:** Images, text, audio, video, and code.
#
# Depending on the type of AI, data is fed into the system either labeled (e.g., "this is a picture of a cat") or unlabeled (e.g., "find patterns in these 1 million cat and dog pictures").
#
# ### 2. The Engine: Algorithms and Models
# An algorithm is a set of rules or instructions a computer follows. In AI, these algorithms form a **model**. The model is the mathematical representation of what the AI has learned.
#
# While AI encompasses many approaches (like logic-based rule systems used in the 1980s), modern AI is almost entirely driven by **Machine Learning (ML)** and its subfield, **Deep Learning (DL)**.
#
# * **Machine Learning (ML):** Instead of manually programming rules (e.g., "if an object has whiskers and purrs, it’s a cat"), programmers give the computer an algorithm and data, and let the computer figure out the rules itself.
# * **Deep Learning (DL):** A subset of ML inspired by the human brain. It uses **Artificial Neural Networks (ANNs)** with many layers (hence "deep") to process complex data like speech and images.
#
# ---
#
# ### 3. The Process: How Training Works
# Training is the process by which an AI model learns from data. This usually happens in three main ways:
#
# #### A. Supervised Learning
# * **How it works:** The AI is given input data paired with correct answers (labels).
# * **Example:** Showing an AI thousands of photos labeled "spam" or "not spam."
# * **Goal:** The AI compares its own prediction to the correct label, calculates its error (using a "loss function"), and adjusts its internal math (parameters/weights) to get closer to the right answer next time. This is done through **gradient descent** (mathematically sliding down toward the lowest possible error).
#
# #### B. Unsupervised Learning
# * **How it works:** The AI is given unlabeled data and tasked with finding hidden patterns or structures on its own.
# * **Example:** Feeding an AI customer purchase history without telling it anything. The AI might independently discover groups of customers who buy similar products (clustering).
#
# #### C. Reinforcement Learning
# * **How it works:** The AI learns by trial and error in an environment (often a simulation or game) to achieve a goal. It receives "rewards" for good actions and "penalties" for bad ones.
# * **Example:** Teaching an AI to play chess or drive a self-driving car. It tries millions of moves, remembering which ones led to winning the game.
#
# ---
#
# ### 4. The Anatomy of Modern AI: Neural Networks
# Because Deep Learning powers modern breakthroughs (like ChatGPT, Midjourney, and self-driving cars), it’s worth looking inside a neural network:
#
# 1. **Input Layer:** Receives the raw data (e.g., the pixels of an image).
# 2. **Hidden Layers:** Layers of artificial "neurons" that process the data.
#    * *Early layers* might detect simple things like edges and lines in an image.
#    * *Middle layers* combine edges to detect shapes (e.g., a circle or triangle).
#    * *Later layers* combine shapes to recognize complex features (e.g., an eye, a nose, or a full face).
# 3. **Output Layer:** Produces the final result (e.g., "This is a 95% probability of being a human face").
#
# Each connection between neurons has a **weight** (importance) and a **bias** (threshold). Learning is simply the process of tweaking these billions of weights and biases until the outputs are accurate.
#
# ---
#
# ### 5. Specialized AI Architectures
# Different tasks require different types of AI brains:
# * **Convolutional Neural Networks (CNNs):** Specialized in processing grid-like data, primarily used in computer vision (image and video recognition).
# * **Recurrent Neural Networks (RNNs) & Transformers:** Specialized in sequential data like text and speech. **Transformers** (the 'T' in GPT) revolutionized AI by using "attention mechanisms" to understand the context of words in a sentence, no matter how far apart they are.
# * **Diffusion Models:** Used in generative AI for images (like DALL-E). They start with random static (noise) and gradually shape it into a clear image based on a text prompt.
#
# ---
#
# ### 6. Hardware: The Muscle
# Training modern AI requires immense computational power.
# * **GPUs (Graphics Processing Units):** Originally built for rendering video game graphics, GPUs are exceptional at performing thousands of mathematical calculations simultaneously, making them the backbone of AI training.
# * **TPUs (Tensor Processing Units) and specialized AI chips:** Custom hardware designed specifically to accelerate machine learning workloads.
#
# ---
#
# ### Summary: From Input to Output
# When you use an AI tool today, here is what happens in milliseconds:
# 1. **Inference:** The trained model is loaded onto a server.
# 2. **You provide an input:** (e.g., "Write a poem about a robot").
# 3. **Tokenization:** The text is broken down into numbers (tokens) that the computer understands.
# 4. **Processing:** The numbers pass through billions of neural network parameters, calculating probabilities for the next best word based on everything it read during training.
# 5. **Decoding:** The output numbers are translated back into human language and displayed on your screen.
